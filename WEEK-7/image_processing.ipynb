# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from os import walk
import os
import glob
import tensorflow as tf

# %%
imgEva = cv2.imread('Eva.jpg',1)

plt.imshow(imgEva)

# %%
imgEva = cv2.line(imgEva, (0, 0), (300, 511), (255, 0, 0), 5)

plt.imshow(imgEva)

# %%
imgburano = cv2.imread('burano.jpg',1) 

plt.imshow(imgburano)

# %%
imgburano = cv2.line(imgburano, (0, 0), (300, 600), (255, 0, 0), 5)

plt.imshow(imgburano)

# %%
imgEva = cv2.rectangle(imgEva, (50, 30), (250, 230), (0, 255, 0), 3)

plt.imshow(imgEva)

# %%
imgEva = cv2.circle(imgEva, (150, 200), 150, (0, 0, 255), 5)
plt.imshow(imgEva)

# %%
import cv2 
 # Load the image 
image = cv2.imread("burano.jpg") 
 # Define the coordinates of the region you want to crop (top left and bottom right) 
top_left = (100, 100) 
bottom_right = (400, 300) 
 # Crop the image 
cropped_image =image[top_left[1]:bottom_right[1],top_left[0]:bottom_right[0]] 
 
# Save the cropped image to a file 
cv2.imwrite("cropped_image.jpg", cropped_image) 
 
# Display the cropped image (optional) 
cv2.imshow("Cropped Image", cropped_image) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
