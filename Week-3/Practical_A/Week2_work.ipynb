# %%
# Importing libraries
import pandas as pd

# %%
# we can set numbers for how many rows and columns will be displayed
pd.set_option('display.min_rows', 10) #default will be 10
pd.set_option('display.max_columns', 20)

# %%
# read csv file

df = pd.read_csv('online_store_customer_data.csv')
df.head(3)
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status State_names  \
# 0         1/1/2019          151200  Female  19.0         Single      Kansas
# 1         1/1/2019          151201    Male  49.0         Single    Illinois
# 2         1/1/2019          151202    Male  63.0        Married  New Mexico
#
#   Segment Employees_status Payment_method  Referal  Amount_spent
# 0   Basic     Unemployment          Other      1.0       2051.36
# 1   Basic    self-employed           Card      0.0        544.04
# 2   Basic          workers         PayPal      1.0       1572.60

# %% [markdown]
# # Task 1
#
# #1. Inconsistent Data.
#
# Task 1: Copy the jupyter notebook of week2 solution, available on Brightspace.
#
# •  Download “Week2_work.ipynb” from Brightspace and upload it to your Google Colab or open it in Jupyter.
# Some rows need to be deleted depending upon some values in columns.
#
# • Find unique values in columns ‘Payment_method’ and ‘Employees_status’.
#
# • It is ok to have ‘Unemployed’ as category in Employee status and ‘Others’ in Payment method. But we don’t want to keep records of customers whose payment type is ‘others and employee status is ‘unemployed’.
#
# • Drop rows where Employees_status is unemployment and Payment_method is other.
#
# df[(df['Employees_status']=='Unemployment') &
# (df['Payment_method']=='Other')].index
#
# • The above code will return indexes of rows where Employees_status is unemployment and
# Payement_method is other.
#
# • Pass it to the drop function to delete the rows.
#
# df = df.drop(df[(df['Employees_status']=='Unemployment') &
# (df['Payment_method']=='Other')].index)
#
#        Print df.shape before and after drop to find out if the rows were deleted.

# %%
## unique values

emp_status = df['Employees_status'].value_counts()
emp_status
# Out:
# Employees_status
# Employees        972
# workers          798
# self-employed    487
# Unemployment     255
# Name: count, dtype: int64

# %%
emp_pay_method = df['Payment_method'].value_counts()
emp_pay_method
# Out:
# Payment_method
# PayPal    1168
# Card       749
# Other      595
# Name: count, dtype: int64

# %%
# •	Find out the number of rows and columns in your data frame by using function shape
print("Data Shape: ", df.shape)
print("Rows in Data: ", df.shape[0])
print("Columns in Data: ", df.shape[1])
# Out:
# Data Shape:  (2512, 10)
# Rows in Data:  2512
# Columns in Data:  10

# %%
update_df = df[(df['Employees_status']=='Unemployment') & (df['Payment_method']=='Other')].index
update_df
# Out:
# Index([   0,   38,   72,  102,  105,  109,  112,  127,  131,  168,  178,  202,
#         245,  282,  326,  352,  406,  416,  556,  642,  654,  655,  724,  893,
#         930,  931,  945,  994, 1023, 1089, 1107, 1149, 1241, 1252, 1312, 1324,
#        1330, 1348, 1493, 1506, 1567, 1588, 1589, 1615, 1616, 1653, 1726, 1803,
#        1838, 1867, 2004, 2021, 2086, 2120, 2228, 2287, 2323, 2371],
#       dtype='int64')

# %%
# Delete or dropping the unemployed and others colum 

drop_df = df.drop(df[(df['Employees_status']=='Unemployment') & (df['Payment_method']=='Other')].index)
drop_df.head(50)
# Out:
#     Transaction_ID  Gender   Age Marital_status     State_names   Segment  \
# 1           151201    Male  49.0         Single        Illinois     Basic
# 2           151202    Male  63.0        Married      New Mexico     Basic
# 3           151203  Female  18.0         Single        Virginia  Platinum
# 4           151204    Male  27.0         Single     Connecticut     Basic
# 5           151205    Male  71.0         Single          Hawaii     Basic
# 22          workers           Card      0.0    719.130000
# 23    self-employed         PayPal      1.0   2407.360000
# 24        Employees         PayPal      0.0   2737.410000
# 25    self-employed          Other      1.0   1514.750000
# 26    self-employed           Card      1.0    293.580000
# 27          workers           Card      1.0   1094.670000
# 28    self-employed         PayPal      1.0    233.050000
# 29        Employees          Other      1.0   1418.422577
# 30        Employees         PayPal      1.0   1418.422577
# 31        Employees           Card      0.0   2035.070000
# 32        Employees          Other      0.0    128.290000
# 33    self-employed           Card      1.0    628.930000
# 34        Employees           Card      0.0   1729.360000
# 35          workers          Other      1.0   2040.290000
# 36        Employees         PayPal      1.0   2744.880000
# 37        Employees         PayPal      1.0    351.880000
# 39     Unemployment         PayPal      1.0   2418.620000
# 40          workers           Card      0.0   2734.150000
# 41          workers         PayPal      1.0   2851.830000
# 42    self-employed         PayPal      1.0    938.160000
# 43          workers         PayPal      1.0    281.920000
# 44        Employees         PayPal      1.0    747.680000
# 45     Unemployment           Card      1.0   1784.150000
# 46        Employees         PayPal      1.0   1115.900000
# 47        Employees          Other      0.0   1902.470000
# 48    self-employed           Card      1.0   1949.920000
# 49     Unemployment           Card      0.0   1418.422577
# 50        Employees         PayPal      1.0    583.720000
# 51    self-employed           Card      0.0   2445.030000

# %%
# •	Display the statistical summary of your data frame by using describe() function.
df.describe()
# Out:
#        Transaction_ID          Age      Referal  Amount_spent
# count     2512.000000  2512.000000  2512.000000   2512.000000
# mean    152443.931131    46.637652     0.652100   1418.422577
# std        724.580482    18.033540     0.461467    835.101648
# min     151200.000000    15.000000     0.000000      2.090000
# 25%     151815.750000    32.000000     0.000000    734.862500
# 50%     152443.500000    46.637652     1.000000   1418.422577
# 75%     153071.250000    62.000000     1.000000   1955.997500
# max     153699.000000    78.000000     1.000000   2999.980000

# %%
# •	Use function info to find out columns, their data types, and number of non-null values in each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    2512 non-null   int64
#  1   Gender            2512 non-null   object
#  2   Age               2512 non-null   float64
#  3   Marital_status    2512 non-null   object
#  4   State_names       2512 non-null   object
#  5   Segment           2512 non-null   object
#  6   Employees_status  2512 non-null   object
#  7   Payment_method    2512 non-null   object
#  8   Referal           2512 non-null   float64
#  9   Amount_spent      2512 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 196.4+ KB

# %%
# •	Use function value_counts() to find out unique values and their frequency in columns Gender, Marital_status, and Payement_method.
print(df['Gender'].value_counts())
print(df['Marital_status'].value_counts())
print(df['Payment_method'].value_counts())
# Out:
# Gender
# Female    1384
# Male      1128
# Name: count, dtype: int64
# Marital_status
# Married    1473
# Single     1039
# Name: count, dtype: int64
# Payment_method
# PayPal    1168
# Card       749
# Other      595
# Name: count, dtype: int64

# %% [markdown]
# # Task 2

# %%
df.isna().sum()
# Out:
# Transaction_ID      0
# Gender              0
# Age                 0
# Marital_status      0
# State_names         0
# Segment             0
# Employees_status    0
# Payment_method      0
# Referal             0
# Amount_spent        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Transaction_date      0
# Transaction_ID        0
# Gender               28
# Age                  42
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             155
# Amount_spent        242
# dtype: int64

# %% [markdown]
# # Task 3

# %%
# Drop column Transaction_date from main dataframe
df.drop(columns = 'Transaction_date', inplace=True)

# %%
# Drop column “Amount_spent” using df.drop(‘column name’, inplace=True)
df_temp = df.copy()
df_temp.drop(columns=['Amount_spent'], inplace=True)
df_temp.head(3)
# Out:
#    Transaction_ID  Gender   Age Marital_status State_names Segment  \
# 0          151200  Female  19.0         Single      Kansas   Basic
# 1          151201    Male  49.0         Single    Illinois   Basic
# 2          151202    Male  63.0        Married  New Mexico   Basic
#
#   Employees_status Payment_method  Referal
# 0     Unemployment          Other      1.0
# 1    self-employed           Card      0.0
# 2          workers         PayPal      1.0

# %%
print(df_temp.isnull().sum())
# Out:
# Transaction_ID        0
# Gender               28
# Age                  42
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             155
# dtype: int64

# %%
# Remove rows from data frame where Employee_status values are missing.

df_temp.dropna(subset = ["Employees_status"], inplace=True)
df_temp.isnull().sum()
# Out:
# Transaction_ID        0
# Gender               27
# Age                  42
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status      0
# Payment_method        0
# Referal             154
# dtype: int64

# %%
# Replace Amount_spent missing values with the mean value of amount_spent.
mean_AS = df['Amount_spent'].mean()
df['Amount_spent'].fillna(mean_AS, inplace=True)
df.isnull().sum()
# Out:
# C:\Users\hussa\AppData\Local\Temp\ipykernel_11940\282788926.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Amount_spent'].fillna(mean_AS, inplace=True)
# Transaction_ID        0
# Gender               28
# Age                  42
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             155
# Amount_spent          0
# dtype: int64

# %%
# Replace missing values in Age with the mean age value.
mean_Age = df['Age'].mean()
df['Age'].fillna(mean_Age, inplace=True)
df.isnull().sum()
# Out:
# C:\Users\hussa\AppData\Local\Temp\ipykernel_11940\87484663.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(mean_Age, inplace=True)
# Transaction_ID        0
# Gender               28
# Age                   0
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             155
# Amount_spent          0
# dtype: int64

# %%
# Replace missing values in Referal with the mean Referal value.
mean_R = df['Referal'].mean()
df['Referal'].fillna(mean_R, inplace=True)
df.isnull().sum()
# Out:
# C:\Users\hussa\AppData\Local\Temp\ipykernel_11940\2169838137.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Referal'].fillna(mean_R, inplace=True)
# Transaction_ID       0
# Gender              28
# Age                  0
# Marital_status       0
# State_names          0
# Segment              0
# Employees_status    26
# Payment_method       0
# Referal              0
# Amount_spent         0
# dtype: int64

# %%
# Replace missing values in “Employee_status” with the mode value of column “Employee_status”.
mode_emp = df['Employees_status'].mode().iloc[0]
df['Employees_status'].fillna(mode_emp, inplace=True)
df.isnull().sum()
# Out:
# C:\Users\hussa\AppData\Local\Temp\ipykernel_11940\1150892309.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Employees_status'].fillna(mode_emp, inplace=True)
# Transaction_ID       0
# Gender              28
# Age                  0
# Marital_status       0
# State_names          0
# Segment              0
# Employees_status     0
# Payment_method       0
# Referal              0
# Amount_spent         0
# dtype: int64

# %%
# Replace missing values in Gender with the mode value of column Gender.
mode_Gender = df['Gender'].mode().iloc[0]
df['Gender'].fillna(mode_Gender, inplace=True)
df.isnull().sum()
# Out:
# C:\Users\hussa\AppData\Local\Temp\ipykernel_11940\2346130288.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(mode_Gender, inplace=True)
# Transaction_ID      0
# Gender              0
# Age                 0
# Marital_status      0
# State_names         0
# Segment             0
# Employees_status    0
# Payment_method      0
# Referal             0
# Amount_spent        0
# dtype: int64
