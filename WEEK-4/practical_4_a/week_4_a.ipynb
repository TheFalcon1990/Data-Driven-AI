# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Fetching data
fully_df = pd.read_csv('online_store_customer_data.csv')
fully_df.head()
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 0     Basic     Unemployment          Other      1.0       2051.36
# 1     Basic    self-employed           Card      0.0        544.04
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      1.0       1199.79
# 4     Basic    self-employed           Card      0.0           NaN

# %%
dict_line = {
    'year' : [2016,2017,2018,2019,2020,2021],
    'price': [200, 250, 260, 220, 280, 300]
}
df_line = pd.DataFrame(dict_line)

# Using plotting() method on the data frame 
df_line.plot('year', 'price' )
# Out:
# <Axes: xlabel='year'>

# %%
# Graph for payment method

pay_df = fully_df = pd.DataFrame(fully_df[['Payment_method']].value_counts()) 
print(pay_df)
# Out:
#                 count
# Payment_method
# PayPal           1168
# Card              749
# Other             595

# %%
#
pay_df = pay_df.reset_index()

# %%
# only to rename on specific column
pay_df.rename(columns={'count' : 'Count'}, inplace=True) 
print(pay_df)

# # renaming all columns
# pay_df.columns = ['Payment_method', 'Count'] 
# print(pay_df)
# Out:
#   Payment_method  Count
# 0         PayPal   1168
# 1           Card    749
# 2          Other    595

# %%
#Create a line graph using the plot function.  
pay_df.plot('Payment_method', 'Count', kind='line')
# Out:
# <Axes: xlabel='Payment_method'>

# %%
pay_df = fully_df = pd.DataFrame(fully_df[['Segment']].value_counts()) 
print(pay_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[270], line 1
# ----> 1 pay_df = fully_df = pd.DataFrame(fully_df[['Segment']].value_counts())
#       2 print(pay_df)
#
# File c:\Users\hussa\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\hussa\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...

# %%
# Plotting segment
fully_df = pd.read_csv('online_store_customer_data.csv')
fully_df ["Segment"].value_counts().plot(kind='line',title="Payment_method")
# Out:
# <Axes: title={'center': 'Payment_method'}, xlabel='Segment'>

# %%
# Not working properly need to check later on
fully_df = pd.read_csv('online_store_customer_data.csv')
fully_df ["Payment_method"].value_counts().plot(kind='line',title="Payment_method")
# Out:
# <Axes: title={'center': 'Payment_method'}, xlabel='Payment_method'>

# %%
fully_df['Employees_status'].value_counts().plot(kind='bar');

# %%
fully_df['Employees_status'].value_counts().plot(kind='bar', 
title="Employee_Status", figsize= [5,5]);

# %%
fully_df['Employees_status'].value_counts().plot(kind='barh');

# %%
fully_df['State_names'].value_counts().plot(kind='bar', 
title="State_names", figsize= [10,10]);

# %%
# Pie Plot
fully_df['Segment'].value_counts().plot(kind='pie');

# %%
fully_df["Gender"].value_counts().plot(title="Gender",kind='pie', autopct='%.1f%%', shadow=True)
# Out:
# <Axes: title={'center': 'Gender'}, ylabel='count'>

# %%
# Histogram 

fully_df.plot( 
    y='Age', 
    kind='hist', 
    bins=20 
)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Box Plot

fully_df.plot(y=['Amount_spent'], kind='box');

# %%
fully_df = pd.read_csv('online_store_customer_data.csv')

# %%
new_data = [
{'Transaction_ID': 160000, 'Gender': 'Male','Age': 40, 
'Marital_status': 'Married','State_names': 'Hawaii', 'Segment': 
'Basic','Employees_status': 'workers', 'Payment_method': 
'PayPal','Referal': 1.0, 'Amount_spent': 4000},

{'Transaction_ID': 160001, 'Gender': 'Male','Age': 40, 
'Marital_status': 'Married','State_names': 'Hawaii', 'Segment': 
'Basic','Employees_status': 'workers', 'Payment_method': 
'PayPal','Referal': 1.0, 'Amount_spent': 5000},

{'Transaction_ID': 160002, 'Gender': 'Male','Age': 40, 
'Marital_status': 'Married','State_names': 'Hawaii', 'Segment': 
'Basic','Employees_status': 'workers', 'Payment_method': 
'PayPal','Referal': 1.0, 'Amount_spent': 6000},
 
{'Transaction_ID': 160003, 'Gender': 'Male','Age': 40, 
'Marital_status': 'Married','State_names': 'Hawaii', 'Segment': 
'Basic','Employees_status': 'workers', 'Payment_method': 
'PayPal','Referal': 1.0, 'Amount_spent': 7000},
 
{'Transaction_ID': 160004, 'Gender': 'Male','Age': 40, 
'Marital_status': 'Married','State_names': 'Hawaii', 'Segment': 
'Basic','Employees_status': 'workers', 'Payment_method': 
'PayPal','Referal': 1.0, 'Amount_spent': 8000}, 
 
{'Transaction_ID': 160005, 'Gender': 'Male','Age': 40, 
'Marital_status': 'Married','State_names': 'Hawaii', 'Segment': 
'Basic','Employees_status': 'workers', 'Payment_method': 
'PayPal','Referal': 1.0, 'Amount_spent': 9000}
]

fully_df = fully_df._append(new_data,ignore_index=True)
fully_df
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2531              NaN          160001    Male  40.0        Married
# 2532              NaN          160002    Male  40.0        Married
# 2533              NaN          160003    Male  40.0        Married
# 2534              NaN          160004    Male  40.0        Married
# 2535              NaN          160005    Male  40.0        Married
#
#       State_names   Segment Employees_status Payment_method  Referal  \
# 0          Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
fully_df = pd.read_csv('online_store_customer_data.csv')

# %%
fully_df.boxplot(by ='Employees_status', column =['Amount_spent'],figsize=(6,6) , grid=False,showfliers = False)
# Out:
# <Axes: title={'center': 'Amount_spent'}, xlabel='Employees_status'>
